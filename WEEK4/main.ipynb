# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('world-population.xlsm')

# %%
df
x = df['Year']
y = df['Population']
plt.plot(x,y)
plt.show()

# %%
plt.step(x,y)
